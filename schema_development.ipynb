# %% [markdown]
# #

# %% [markdown]
# # Gen3 Schema Development Framework
#
# This notebook provides a framework for developing a gen3 data schema using gdocs as a template. Notebook from Joshua Harris, Australian BioCommons. Has been edited for Thyroid group use case.

# %%
# !git clone https://github.com/AustralianBioCommons/gen3schemadev.git
# !cd ./gen3schemadev
# !python3 -m venv .venv
# !source .venv/bin/activate
# !pip3 install -r requirements.txt
# Out:
# Cloning into 'gen3schemadev'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 636 (delta 136), reused 170 (delta 114), pack-reused 433
# Receiving objects: 100% (636/636), 102.23 MiB | 14.53 MiB/s, done.
# Resolving deltas: 100% (336/336), done.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### Pulling data schema from google sheets
# - pulls design from the following google sheet template [link](https://docs.google.com/spreadsheets/d/1zjDBDvXgb0ydswFBwy47r2c8V1TFnpUj1jcG0xsY7ZI/edit?usp=sharing)

# %%
# Pulling data schema from google sheets
# Note this is loads a gdoc template 
# !rm -R schema_out
# !python3 sheet2yaml-CLI.py --google-id '1zjDBDvXgb0ydswFBwy47r2c8V1TFnpUj1jcG0xsY7ZI' --objects-gid 0 --links-gid 270346573 --properties-gid 613332252 --enums-gid 1807456496

# %%
# Run if  umccr-dict does not exist
# !cd "$(pwd)/../" && git clone https://github.com/AustralianBioCommons/umccr-dictionary.git
# Out:
# fatal: destination path 'umccr-dictionary' already exists and is not an empty directory.

# %%
# Moving schema_out to umccr-dictionary
# !mkdir -p ../umccr-dictionary/dictionary/schema_dev/gdcdictionary/schemas
# !cp schema_out/* ../umccr-dictionary/dictionary/schema_dev/gdcdictionary/schemas/
# !ls -lsha ../umccr-dictionary/dictionary/schema_dev/gdcdictionary/schemas/
# Out:
# total 240
#   0 drwxr-xr-x@ 13 harrijh  staff   416B Apr 19 14:38 .
#   0 drwxr-xr-x@  3 harrijh  staff    96B Apr 19 14:38 ..
#  16 -rw-r--r--@  1 harrijh  staff   4.0K Apr 19 14:45 _definitions.yaml
#   8 -rw-r--r--@  1 harrijh  staff    25B Apr 19 14:45 _settings.yaml
# 144 -rw-r--r--@  1 harrijh  staff    72K Apr 19 14:45 _terms.yaml
#  16 -rw-r--r--@  1 harrijh  staff   4.8K Apr 19 14:45 core_metadata_collection.yaml
#   8 -rw-r--r--@  1 harrijh  staff   974B Apr 19 14:45 demographic.yaml
#   8 -rw-r--r--@  1 harrijh  staff   1.2K Apr 19 14:45 lipidomics_file.yaml
#   8 -rw-r--r--@  1 harrijh  staff   1.9K Apr 19 14:45 medical_history.yaml
#   8 -rw-r--r--@  1 harrijh  staff   672B Apr 19 14:45 program.yaml
#   8 -rw-r--r--@  1 harrijh  staff   3.4K Apr 19 14:45 project.yaml
#   8 -rw-r--r--@  1 harrijh  staff   1.1K Apr 19 14:45 sample.yaml
#   8 -rw-r--r--@  1 harrijh  staff   1.3K Apr 19 14:45 subject.yaml

# %%
# loading containers dictionary YAMLs to JSON
# !cd ../umccr-dictionary && make down
# !cd ../umccr-dictionary && make pull
# !cd ../umccr-dictionary && make up
# !cd ../umccr-dictionary && make ps
# Out:
# Using .env-sample
# [+] Running 6/0
#  ✔ Container dmutils                 Removed                               0.0s
#  ✔ Container ddimporter              Removed                               0.0s
#  ✔ Container g3po                    Removed                               0.0s
#  ✔ Container ddpostgres              Removed                               0.0s
#  ✔ Container ddvis                   Removed                               0.0s
#  ✔ Container ddsim                   Removed                               0.0s
#  ⠋ Network umccr-dictionary_default  Removing                              0.1s
# [+] Running 7/7
#  ✔ Container dmutils                 Removed                               0.0s
#  ✔ Container ddimporter              Removed                               0.0s
#  ✔ Container g3po                    Removed                               0.0s
#  ✔ Container ddpostgres              Removed                               0.0s
#  ✔ Container ddvis                   Removed                               0.0s
#  ✔ Container ddsim                   Removed                               0.0s
#  ✔ Network umccr-dictionary_default  Removed                               0.1s
# Using .env-sample
# [+] Pulling 0/0
#  ⠋ postgres Pulling                                                        0.1s
#  ⠋ ddvis Pulling                                                           0.1s
#  ⠋ g3po Pulling                                                            0.1s
#  ⠋ ddimporter Pulling                                                      0.1s
#  ⠋ dmutils Pulling                                                         0.1s
#  ⠋ ddsim Pulling                                                           0.1s
# [+] Pulling 0/6
#  ⠙ postgres Pulling                                                        0.2s
#  ⠙ ddvis Pulling                                                           0.2s
#  ⠙ g3po Pulling                                                            0.2s
#  ⠙ ddimporter Pulling                                                      0.2s
#  ⠙ dmutils Pulling                                                         0.2s
#  ⠙ ddsim Pulling                                                           0.2s
# [+] Pulling 0/6
#  ⠹ postgres Pulling                                                        0.3s
#  ⠹ ddvis Pulling                                                           0.3s
#  ⠹ g3po Pulling                                                            0.3s
#  ⠹ ddimporter Pulling                                                      0.3s
#  ⠹ dmutils Pulling                                                         0.3s
#  ⠹ ddsim Pulling                                                           0.3s
# [+] Pulling 0/6
#  ⠸ postgres Pulling                                                        0.4s
#  ⠸ ddvis Pulling                                                           0.4s
#  ⠸ g3po Pulling                                                            0.4s
#  ⠸ ddimporter Pulling                                                      0.4s
#  ⠸ dmutils Pulling                                                         0.4s
#  ⠸ ddsim Pulling                                                           0.4s
# [+] Pulling 0/6
#  ⠼ postgres Pulling                                                        0.5s
#  ⠼ ddvis Pulling                                                           0.5s
#  ⠼ g3po Pulling                                                            0.5s
#  ⠼ ddimporter Pulling                                                      0.5s
#  ⠼ dmutils Pulling                                                         0.5s
#  ⠼ ddsim Pulling                                                           0.5s
# [+] Pulling 0/6
#  ⠴ postgres Pulling                                                        0.6s
#  ⠴ ddvis Pulling                                                           0.6s
#  ⠴ g3po Pulling                                                            0.6s
#  ⠴ ddimporter Pulling                                                      0.6s
#  ⠴ dmutils Pulling                                                         0.6s
#  ⠴ ddsim Pulling                                                           0.6s
# [+] Pulling 0/6
#  ⠦ postgres Pulling                                                        0.7s
#  ⠦ ddvis Pulling                                                           0.7s
#  ⠦ g3po Pulling                                                            0.7s
#  ⠦ ddimporter Pulling                                                      0.7s
#  ⠦ dmutils Pulling                                                         0.7s
#  ⠦ ddsim Pulling                                                           0.7s
# [+] Pulling 0/6
#  ⠧ postgres Pulling                                                        0.8s
#  ⠧ ddvis Pulling                                                           0.8s
#  ⠧ g3po Pulling                                                            0.8s
#  ⠧ ddimporter Pulling                                                      0.8s
#  ⠧ dmutils Pulling                                                         0.8s
#  ⠧ ddsim Pulling                                                           0.8s
# [+] Pulling 0/6
#  ⠇ postgres Pulling                                                        0.9s
#  ⠇ ddvis Pulling                                                           0.9s
#  ⠇ g3po Pulling                                                            0.9s
#  ⠇ ddimporter Pulling                                                      0.9s
#  ⠇ dmutils Pulling                                                         0.9s
#  ⠇ ddsim Pulling                                                           0.9s
# [+] Pulling 0/6
#  ⠏ postgres Pulling                                                        1.0s
#  ⠏ ddvis Pulling                                                           1.0s
#  ⠏ g3po Pulling                                                            1.0s
#  ⠏ ddimporter Pulling                                                      1.0s
#  ⠏ dmutils Pulling                                                         1.0s
#  ⠏ ddsim Pulling                                                           1.0s
# [+] Pulling 0/6
#  ⠋ postgres Pulling                                                        1.1s
#  ⠋ ddvis Pulling                                                           1.1s
#  ⠋ g3po Pulling                                                            1.1s
#  ⠋ ddimporter Pulling                                                      1.1s
#  ⠋ dmutils Pulling                                                         1.1s
#  ⠋ ddsim Pulling                                                           1.1s
# [+] Pulling 0/6
#  ⠙ postgres Pulling                                                        1.2s
#  ⠙ ddvis Pulling                                                           1.2s
#  ⠙ g3po Pulling                                                            1.2s
#  ⠙ ddimporter Pulling                                                      1.2s
#  ⠙ dmutils Pulling                                                         1.2s
#  ⠙ ddsim Pulling                                                           1.2s
# [+] Pulling 0/6
#  ⠹ postgres Pulling                                                        1.3s
#  ⠹ ddvis Pulling                                                           1.3s
#  ⠹ g3po Pulling                                                            1.3s
#  ⠹ ddimporter Pulling                                                      1.3s
#  ⠹ dmutils Pulling                                                         1.3s
#  ⠹ ddsim Pulling                                                           1.3s
# [+] Pulling 0/6
#  ⠸ postgres Pulling                                                        1.4s
#  ⠸ ddvis Pulling                                                           1.4s
#  ⠸ g3po Pulling                                                            1.4s
#  ⠸ ddimporter Pulling                                                      1.4s
#  ⠸ dmutils Pulling                                                         1.4s
#  ⠸ ddsim Pulling                                                           1.4s
# [+] Pulling 0/6
#  ⠼ postgres Pulling                                                        1.5s
#  ⠼ ddvis Pulling                                                           1.5s
#  ⠼ g3po Pulling                                                            1.5s
#  ⠼ ddimporter Pulling                                                      1.5s
#  ⠼ dmutils Pulling                                                         1.5s
#  ⠼ ddsim Pulling                                                           1.5s
# [+] Pulling 0/6
#  ⠴ postgres Pulling                                                        1.6s
#  ⠴ ddvis Pulling                                                           1.6s
#  ⠴ g3po Pulling                                                            1.6s
#  ⠴ ddimporter Pulling                                                      1.6s
#  ⠴ dmutils Pulling                                                         1.6s
#  ⠴ ddsim Pulling                                                           1.6s
# [+] Pulling 0/6
#  ⠦ postgres Pulling                                                        1.7s
#  ⠦ ddvis Pulling                                                           1.7s
#  ⠦ g3po Pulling                                                            1.7s
#  ⠦ ddimporter Pulling                                                      1.7s
#  ⠦ dmutils Pulling                                                         1.7s
#  ⠦ ddsim Pulling                                                           1.7s
# [+] Pulling 0/6
#  ⠧ postgres Pulling                                                        1.8s
#  ⠧ ddvis Pulling                                                           1.8s
#  ⠧ g3po Pulling                                                            1.8s
#  ⠧ ddimporter Pulling                                                      1.8s
#  ⠧ dmutils Pulling                                                         1.8s
#  ⠧ ddsim Pulling                                                           1.8s
# [+] Pulling 0/6
#  ⠇ postgres Pulling                                                        1.9s
#  ⠇ ddvis Pulling                                                           1.9s
#  ⠇ g3po Pulling                                                            1.9s
#  ⠇ ddimporter Pulling                                                      1.9s
#  ⠇ dmutils Pulling                                                         1.9s
#  ⠇ ddsim Pulling                                                           1.9s
# [+] Pulling 0/6
#  ⠏ postgres Pulling                                                        2.0s
#  ⠏ ddvis Pulling                                                           2.0s
#  ⠏ g3po Pulling                                                            2.0s
#  ⠏ ddimporter Pulling                                                      2.0s
#  ⠏ dmutils Pulling                                                         2.0s
#  ⠏ ddsim Pulling                                                           2.0s
# [+] Pulling 0/6
#  ⠋ postgres Pulling                                                        2.1s
#  ⠋ ddvis Pulling                                                           2.1s
#  ⠋ g3po Pulling                                                            2.1s
#  ⠋ ddimporter Pulling                                                      2.1s
#  ⠋ dmutils Pulling                                                         2.1s
#  ⠋ ddsim Pulling                                                           2.1s
# [+] Pulling 0/6
#  ⠙ postgres Pulling                                                        2.2s
#  ⠙ ddvis Pulling                                                           2.2s
#  ⠙ g3po Pulling                                                            2.2s
#  ⠙ ddimporter Pulling                                                      2.2s
#  ⠙ dmutils Pulling                                                         2.2s
#  ⠙ ddsim Pulling                                                           2.2s
# [+] Pulling 0/6
#  ⠹ postgres Pulling                                                        2.3s
#  ⠹ ddvis Pulling                                                           2.3s
#  ⠹ g3po Pulling                                                            2.3s
#  ⠹ ddimporter Pulling                                                      2.3s
#  ⠹ dmutils Pulling                                                         2.3s
#  ⠹ ddsim Pulling                                                           2.3s
# [+] Pulling 0/6
#  ⠸ postgres Pulling                                                        2.4s
#  ⠸ ddvis Pulling                                                           2.4s
#  ⠸ g3po Pulling                                                            2.4s
#  ⠸ ddimporter Pulling                                                      2.4s
#  ⠸ dmutils Pulling                                                         2.4s
#  ⠸ ddsim Pulling                                                           2.4s
# [+] Pulling 0/6
#  ⠼ postgres Pulling                                                        2.5s
#  ⠼ ddvis Pulling                                                           2.5s
#  ⠼ g3po Pulling                                                            2.5s
#  ⠼ ddimporter Pulling                                                      2.5s
#  ⠼ dmutils Pulling                                                         2.5s
#  ⠼ ddsim Pulling                                                           2.5s
# [+] Pulling 0/6
#  ⠴ postgres Pulling                                                        2.6s
#  ⠴ ddvis Pulling                                                           2.6s
#  ⠴ g3po Pulling                                                            2.6s
#  ⠴ ddimporter Pulling                                                      2.6s
#  ⠴ dmutils Pulling                                                         2.6s
#  ⠴ ddsim Pulling                                                           2.6s
# [+] Pulling 0/6
#  ⠦ postgres Pulling                                                        2.7s
#  ⠦ ddvis Pulling                                                           2.7s
#  ⠦ g3po Pulling                                                            2.7s
#  ⠦ ddimporter Pulling                                                      2.7s
#  ⠦ dmutils Pulling                                                         2.7s
#  ⠦ ddsim Pulling                                                           2.7s
# [+] Pulling 0/6
#  ⠧ postgres Pulling                                                        2.8s
#  ⠧ ddvis Pulling                                                           2.8s
#  ⠧ g3po Pulling                                                            2.8s
#  ⠧ ddimporter Pulling                                                      2.8s
#  ⠧ dmutils Pulling                                                         2.8s
#  ⠧ ddsim Pulling                                                           2.8s
# [+] Pulling 0/6
#  ⠇ postgres Pulling                                                        2.9s
#  ⠇ ddvis Pulling                                                           2.9s
#  ⠇ g3po Pulling                                                            2.9s
#  ⠇ ddimporter Pulling                                                      2.9s
#  ⠇ dmutils Pulling                                                         2.9s
#  ⠇ ddsim Pulling                                                           2.9s
# [+] Pulling 0/6
#  ⠏ postgres Pulling                                                        3.0s
#  ⠏ ddvis Pulling                                                           3.0s
#  ⠏ g3po Pulling                                                            3.0s
#  ⠏ ddimporter Pulling                                                      3.0s
#  ⠏ dmutils Pulling                                                         3.0s
#  ⠏ ddsim Pulling                                                           3.0s
# [+] Pulling 1/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠋ ddvis Pulling                                                           3.1s
#  ⠋ g3po Pulling                                                            3.1s
#  ⠋ ddimporter Pulling                                                      3.1s
#  ⠋ dmutils Pulling                                                         3.1s
#  ⠋ ddsim Pulling                                                           3.1s
# [+] Pulling 1/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠙ ddvis Pulling                                                           3.2s
#  ⠙ g3po Pulling                                                            3.2s
#  ⠙ ddimporter Pulling                                                      3.2s
#  ⠙ dmutils Pulling                                                         3.2s
#  ⠙ ddsim Pulling                                                           3.2s
# [+] Pulling 1/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠹ ddvis Pulling                                                           3.3s
#  ⠹ g3po Pulling                                                            3.3s
#  ⠹ ddimporter Pulling                                                      3.3s
#  ⠹ dmutils Pulling                                                         3.3s
#  ⠹ ddsim Pulling                                                           3.3s
# [+] Pulling 1/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠸ ddvis Pulling                                                           3.4s
#  ⠸ g3po Pulling                                                            3.4s
#  ⠸ ddimporter Pulling                                                      3.4s
#  ⠸ dmutils Pulling                                                         3.4s
#  ⠸ ddsim Pulling                                                           3.4s
# [+] Pulling 1/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠼ ddvis Pulling                                                           3.5s
#  ⠼ g3po Pulling                                                            3.5s
#  ⠼ ddimporter Pulling                                                      3.5s
#  ⠼ dmutils Pulling                                                         3.5s
#  ⠼ ddsim Pulling                                                           3.5s
# [+] Pulling 2/6
#  ✔ postgres Pulled                                                         3.1s
#  ⠴ ddvis Pulling                                                           3.6s
#  ✔ g3po Pulled                                                             3.6s
#  ⠴ ddimporter Pulling                                                      3.6s
#  ⠴ dmutils Pulling                                                         3.6s
#  ⠴ ddsim Pulling                                                           3.6s
# [+] Pulling 4/6
#  ✔ postgres Pulled                                                         3.1s
#  ✔ ddvis Pulled                                                            3.7s
#  ✔ g3po Pulled                                                             3.6s
#  ⠦ ddimporter Pulling                                                      3.7s
#  ✔ dmutils Pulled                                                          3.6s
#  ⠦ ddsim Pulling                                                           3.7s
# [+] Pulling 6/6
#  ✔ postgres Pulled                                                         3.1s
#  ✔ ddvis Pulled                                                            3.7s
#  ✔ g3po Pulled                                                             3.6s
#  ✔ ddimporter Pulled                                                       3.8s
#  ✔ dmutils Pulled                                                          3.6s
#  ✔ ddsim Pulled                                                            3.7s
# Using .env-sample
# [+] Pulling 0/0
#  ⠋ dmutils Pulling                                                         0.1s
#  ⠋ ddsim Pulling                                                           0.1s
#  ⠋ postgres Pulling                                                        0.1s
#  ⠋ g3po Pulling                                                            0.1s
#  ⠋ ddvis Pulling                                                           0.1s
#  ⠋ ddimporter Pulling                                                      0.1s
# [+] Pulling 0/6
#  ⠙ dmutils Pulling                                                         0.2s
#  ⠙ ddsim Pulling                                                           0.2s
#  ⠙ postgres Pulling                                                        0.2s
#  ⠙ g3po Pulling                                                            0.2s
#  ⠙ ddvis Pulling                                                           0.2s
#  ⠙ ddimporter Pulling                                                      0.2s
# [+] Pulling 0/6
#  ⠹ dmutils Pulling                                                         0.3s
#  ⠹ ddsim Pulling                                                           0.3s
#  ⠹ postgres Pulling                                                        0.3s
#  ⠹ g3po Pulling                                                            0.3s
#  ⠹ ddvis Pulling                                                           0.3s
#  ⠹ ddimporter Pulling                                                      0.3s
# [+] Pulling 0/6
#  ⠸ dmutils Pulling                                                         0.4s
#  ⠸ ddsim Pulling                                                           0.4s
#  ⠸ postgres Pulling                                                        0.4s
#  ⠸ g3po Pulling                                                            0.4s
#  ⠸ ddvis Pulling                                                           0.4s
#  ⠸ ddimporter Pulling                                                      0.4s
# [+] Pulling 0/6
#  ⠼ dmutils Pulling                                                         0.5s
#  ⠼ ddsim Pulling                                                           0.5s
#  ⠼ postgres Pulling                                                        0.5s
#  ⠼ g3po Pulling                                                            0.5s
#  ⠼ ddvis Pulling                                                           0.5s
#  ⠼ ddimporter Pulling                                                      0.5s
# [+] Pulling 0/6
#  ⠴ dmutils Pulling                                                         0.6s
#  ⠴ ddsim Pulling                                                           0.6s
#  ⠴ postgres Pulling                                                        0.6s
#  ⠴ g3po Pulling                                                            0.6s
#  ⠴ ddvis Pulling                                                           0.6s
#  ⠴ ddimporter Pulling                                                      0.6s
# [+] Pulling 0/6
#  ⠦ dmutils Pulling                                                         0.7s
#  ⠦ ddsim Pulling                                                           0.7s
#  ⠦ postgres Pulling                                                        0.7s
#  ⠦ g3po Pulling                                                            0.7s
#  ⠦ ddvis Pulling                                                           0.7s
#  ⠦ ddimporter Pulling                                                      0.7s
# [+] Pulling 0/6
#  ⠧ dmutils Pulling                                                         0.8s
#  ⠧ ddsim Pulling                                                           0.8s
#  ⠧ postgres Pulling                                                        0.8s
#  ⠧ g3po Pulling                                                            0.8s
#  ⠧ ddvis Pulling                                                           0.8s
#  ⠧ ddimporter Pulling                                                      0.8s
# [+] Pulling 0/6
#  ⠇ dmutils Pulling                                                         0.9s
#  ⠇ ddsim Pulling                                                           0.9s
#  ⠇ postgres Pulling                                                        0.9s
#  ⠇ g3po Pulling                                                            0.9s
#  ⠇ ddvis Pulling                                                           0.9s
#  ⠇ ddimporter Pulling                                                      0.9s
# [+] Pulling 0/6
#  ⠏ dmutils Pulling                                                         1.0s
#  ⠏ ddsim Pulling                                                           1.0s
#  ⠏ postgres Pulling                                                        1.0s
#  ⠏ g3po Pulling                                                            1.0s
#  ⠏ ddvis Pulling                                                           1.0s
#  ⠏ ddimporter Pulling                                                      1.0s
# [+] Pulling 0/6
#  ⠋ dmutils Pulling                                                         1.1s
#  ⠋ ddsim Pulling                                                           1.1s
#  ⠋ postgres Pulling                                                        1.1s
#  ⠋ g3po Pulling                                                            1.1s
#  ⠋ ddvis Pulling                                                           1.1s
#  ⠋ ddimporter Pulling                                                      1.1s
# [+] Pulling 0/6
#  ⠙ dmutils Pulling                                                         1.2s
#  ⠙ ddsim Pulling                                                           1.2s
#  ⠙ postgres Pulling                                                        1.2s
#  ⠙ g3po Pulling                                                            1.2s
#  ⠙ ddvis Pulling                                                           1.2s
#  ⠙ ddimporter Pulling                                                      1.2s
# [+] Pulling 0/6
#  ⠹ dmutils Pulling                                                         1.3s
#  ⠹ ddsim Pulling                                                           1.3s
#  ⠹ postgres Pulling                                                        1.3s
#  ⠹ g3po Pulling                                                            1.3s
#  ⠹ ddvis Pulling                                                           1.3s
#  ⠹ ddimporter Pulling                                                      1.3s
# [+] Pulling 0/6
#  ⠸ dmutils Pulling                                                         1.4s
#  ⠸ ddsim Pulling                                                           1.4s
#  ⠸ postgres Pulling                                                        1.4s
#  ⠸ g3po Pulling                                                            1.4s
#  ⠸ ddvis Pulling                                                           1.4s
#  ⠸ ddimporter Pulling                                                      1.4s
# [+] Pulling 0/6
#  ⠼ dmutils Pulling                                                         1.5s
#  ⠼ ddsim Pulling                                                           1.5s
#  ⠼ postgres Pulling                                                        1.5s
#  ⠼ g3po Pulling                                                            1.5s
#  ⠼ ddvis Pulling                                                           1.5s
#  ⠼ ddimporter Pulling                                                      1.5s
# [+] Pulling 0/6
#  ⠴ dmutils Pulling                                                         1.6s
#  ⠴ ddsim Pulling                                                           1.6s
#  ⠴ postgres Pulling                                                        1.6s
#  ⠴ g3po Pulling                                                            1.6s
#  ⠴ ddvis Pulling                                                           1.6s
#  ⠴ ddimporter Pulling                                                      1.6s
# [+] Pulling 0/6
#  ⠦ dmutils Pulling                                                         1.7s
#  ⠦ ddsim Pulling                                                           1.7s
#  ⠦ postgres Pulling                                                        1.7s
#  ⠦ g3po Pulling                                                            1.7s
#  ⠦ ddvis Pulling                                                           1.7s
#  ⠦ ddimporter Pulling                                                      1.7s
# [+] Pulling 0/6
#  ⠧ dmutils Pulling                                                         1.8s
#  ⠧ ddsim Pulling                                                           1.8s
#  ⠧ postgres Pulling                                                        1.8s
#  ⠧ g3po Pulling                                                            1.8s
#  ⠧ ddvis Pulling                                                           1.8s
#  ⠧ ddimporter Pulling                                                      1.8s
# [+] Pulling 0/6
#  ⠇ dmutils Pulling                                                         1.9s
#  ⠇ ddsim Pulling                                                           1.9s
#  ⠇ postgres Pulling                                                        1.9s
#  ⠇ g3po Pulling                                                            1.9s
#  ⠇ ddvis Pulling                                                           1.9s
#  ⠇ ddimporter Pulling                                                      1.9s
# [+] Pulling 0/6
#  ⠏ dmutils Pulling                                                         2.0s
#  ⠏ ddsim Pulling                                                           2.0s
#  ⠏ postgres Pulling                                                        2.0s
#  ⠏ g3po Pulling                                                            2.0s
#  ⠏ ddvis Pulling                                                           2.0s
#  ⠏ ddimporter Pulling                                                      2.0s
# [+] Pulling 0/6
#  ⠋ dmutils Pulling                                                         2.1s
#  ⠋ ddsim Pulling                                                           2.1s
#  ⠋ postgres Pulling                                                        2.1s
#  ⠋ g3po Pulling                                                            2.1s
#  ⠋ ddvis Pulling                                                           2.1s
#  ⠋ ddimporter Pulling                                                      2.1s
# [+] Pulling 0/6
#  ⠙ dmutils Pulling                                                         2.2s
#  ⠙ ddsim Pulling                                                           2.2s
#  ⠙ postgres Pulling                                                        2.2s
#  ⠙ g3po Pulling                                                            2.2s
#  ⠙ ddvis Pulling                                                           2.2s
#  ⠙ ddimporter Pulling                                                      2.2s
# [+] Pulling 1/6
#  ⠹ dmutils Pulling                                                         2.3s
#  ⠹ ddsim Pulling                                                           2.3s
#  ✔ postgres Pulled                                                         2.3s
#  ⠹ g3po Pulling                                                            2.3s
#  ⠹ ddvis Pulling                                                           2.3s
#  ⠹ ddimporter Pulling                                                      2.3s
# [+] Pulling 1/6
#  ⠸ dmutils Pulling                                                         2.4s
#  ⠸ ddsim Pulling                                                           2.4s
#  ✔ postgres Pulled                                                         2.3s
#  ⠸ g3po Pulling                                                            2.4s
#  ⠸ ddvis Pulling                                                           2.4s
#  ⠸ ddimporter Pulling                                                      2.4s
# [+] Pulling 1/6
#  ⠼ dmutils Pulling                                                         2.5s
#  ⠼ ddsim Pulling                                                           2.5s
#  ✔ postgres Pulled                                                         2.3s
#  ⠼ g3po Pulling                                                            2.5s
#  ⠼ ddvis Pulling                                                           2.5s
#  ⠼ ddimporter Pulling                                                      2.5s
# [+] Pulling 1/6
#  ⠴ dmutils Pulling                                                         2.6s
#  ⠴ ddsim Pulling                                                           2.6s
#  ✔ postgres Pulled                                                         2.3s
#  ⠴ g3po Pulling                                                            2.6s
#  ⠴ ddvis Pulling                                                           2.6s
#  ⠴ ddimporter Pulling                                                      2.6s
# [+] Pulling 1/6
#  ⠦ dmutils Pulling                                                         2.7s
#  ⠦ ddsim Pulling                                                           2.7s
#  ✔ postgres Pulled                                                         2.3s
#  ⠦ g3po Pulling                                                            2.7s
#  ⠦ ddvis Pulling                                                           2.7s
#  ⠦ ddimporter Pulling                                                      2.7s
# [+] Pulling 1/6
#  ⠧ dmutils Pulling                                                         2.8s
#  ⠧ ddsim Pulling                                                           2.8s
#  ✔ postgres Pulled                                                         2.3s
#  ⠧ g3po Pulling                                                            2.8s
#  ⠧ ddvis Pulling                                                           2.8s
#  ⠧ ddimporter Pulling                                                      2.8s
# [+] Pulling 1/6
#  ⠇ dmutils Pulling                                                         2.9s
#  ⠇ ddsim Pulling                                                           2.9s
#  ✔ postgres Pulled                                                         2.3s
#  ⠇ g3po Pulling                                                            2.9s
#  ⠇ ddvis Pulling                                                           2.9s
#  ⠇ ddimporter Pulling                                                      2.9s
# [+] Pulling 5/6
#  ✔ dmutils Pulled                                                          3.0s
#  ✔ ddsim Pulled                                                            3.0s
#  ✔ postgres Pulled                                                         2.3s
#  ⠏ g3po Pulling                                                            3.0s
#  ✔ ddvis Pulled                                                            3.0s
#  ✔ ddimporter Pulled                                                       3.0s
# [+] Pulling 6/6
#  ✔ dmutils Pulled                                                          3.0s
#  ✔ ddsim Pulled                                                            3.0s
#  ✔ postgres Pulled                                                         2.3s
#  ✔ g3po Pulled                                                             3.0s
#  ✔ ddvis Pulled                                                            3.0s
#  ✔ ddimporter Pulled                                                       3.0s
# [+] Running 5/0
#  ⠋ Network umccr-dictionary_default                                                                                                                          Created0.1s
#  ⠋ Container ddsim                                                                                                                                           Starting0.1s
#  ⠋ Container ddpostgres                                                                                                                                      Starting0.1s
#  ⠋ Container ddvis                                                                                                                                           Starting0.1s
#  ⠋ Container dmutils                                                                                                                                         Starting0.1s
#  ⠋ Container ddimporter                                                                                                                                      Starting0.1s
#  ⠋ Container g3po                                                                                                                                            Starting0.1s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 5/12
#  ⠙ Network umccr-dictionary_default                                                                                                                          Created0.2s
#  ⠙ Container ddsim                                                                                                                                           Starting0.2s
#  ⠙ Container ddpostgres                                                                                                                                      Starting0.2s
#  ⠙ Container ddvis                                                                                                                                           Starting0.2s
#  ⠙ Container dmutils                                                                                                                                         Starting0.2s
#  ⠙ Container ddimporter                                                                                                                                      Starting0.2s
#  ⠙ Container g3po                                                                                                                                            Starting0.2s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 5/12
#  ⠹ Network umccr-dictionary_default                                                                                                                          Created0.3s
#  ⠹ Container ddsim                                                                                                                                           Starting0.3s
#  ⠹ Container ddpostgres                                                                                                                                      Starting0.3s
#  ⠹ Container ddvis                                                                                                                                           Starting0.3s
#  ⠹ Container dmutils                                                                                                                                         Starting0.3s
#  ⠹ Container ddimporter                                                                                                                                      Starting0.3s
#  ⠹ Container g3po                                                                                                                                            Starting0.3s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 5/12
#  ⠸ Network umccr-dictionary_default                                                                                                                          Created0.4s
#  ⠸ Container ddsim                                                                                                                                           Starting0.4s
#  ⠸ Container ddpostgres                                                                                                                                      Starting0.4s
#  ⠸ Container ddvis                                                                                                                                           Starting0.4s
#  ⠸ Container dmutils                                                                                                                                         Starting0.4s
#  ⠸ Container ddimporter                                                                                                                                      Starting0.4s
#  ⠸ Container g3po                                                                                                                                            Starting0.4s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 7/12
#  ⠼ Network umccr-dictionary_default                                                                                                                          Created0.5s
#  ⠼ Container ddsim                                                                                                                                           Starting0.5s
#  ⠼ Container ddpostgres                                                                                                                                      Starting0.5s
#  ⠼ Container ddvis                                                                                                                                           Starting0.5s
#  ✔ Container dmutils                                                                                                                                         Started0.4s
#  ⠼ Container ddimporter                                                                                                                                      Starting0.5s
#  ✔ Container g3po                                                                                                                                            Started0.4s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 9/12
#  ⠴ Network umccr-dictionary_default                                                                                                                          Created0.6s
#  ⠴ Container ddsim                                                                                                                                           Starting0.6s
#  ✔ Container ddpostgres                                                                                                                                      Started0.6s
#  ⠴ Container ddvis                                                                                                                                           Starting0.6s
#  ✔ Container dmutils                                                                                                                                         Started0.4s
#  ✔ Container ddimporter                                                                                                                                      Started0.6s
#  ✔ Container g3po                                                                                                                                            Started0.4s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 10/12
#  ⠦ Network umccr-dictionary_default                                                                                                                          Created0.7s
#  ✔ Container ddsim                                                                                                                                           Started0.6s
#  ✔ Container ddpostgres                                                                                                                                      Started0.6s
#  ⠦ Container ddvis                                                                                                                                           Starting0.7s
#  ✔ Container dmutils                                                                                                                                         Started0.4s
#  ✔ Container ddimporter                                                                                                                                      Started0.6s
#  ✔ Container g3po                                                                                                                                            Started0.4s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# [+] Running 11/12
#  ⠧ Network umccr-dictionary_default                                                                                                                          Created0.7s
#  ✔ Container ddsim                                                                                                                                           Started0.6s
#  ✔ Container ddpostgres                                                                                                                                      Started0.6s
#  ✔ Container ddvis                                                                                                                                           Started0.7s
#  ✔ Container dmutils                                                                                                                                         Started0.4s
#  ✔ Container ddimporter                                                                                                                                      Started0.6s
#  ✔ Container g3po                                                                                                                                            Started0.4s
#  ! ddimporter The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested 0.0s
#  ! ddsim The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! dmutils The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested    0.0s
#  ! ddvis The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested      0.0s
#  ! g3po The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested       0.0s
# Using .env-sample
# NAME         IMAGE                               COMMAND                  SERVICE      CREATED        STATUS                  PORTS
# ddimporter   quay.io/umccr/ddimporter            "tail -f /dev/null"      ddimporter   1 second ago   Up Less than a second
# ddpostgres   postgres:9.6                        "docker-entrypoint.s…"   postgres     1 second ago   Up Less than a second   0.0.0.0:5432->5432/tcp
# ddsim        quay.io/cdis/data-simulator:1.3.3   "tail -f /dev/null"      ddsim        1 second ago   Up Less than a second
# ddvis        quay.io/umccr/ddvis                 "/docker-entrypoint.…"   ddvis        1 second ago   Up Less than a second   0.0.0.0:8080->80/tcp
# dmutils      quay.io/umccr/datamodelutils        "tail -f /dev/null"      dmutils      1 second ago   Up Less than a second
# g3po         quay.io/umccr/g3po                  "tail -f /dev/null"      g3po         1 second ago   Up Less than a second

# %%
# compiling and bundling into json
# !cd ../umccr-dictionary && make compile program=schema_dev
# Out:
# Using .env-sample
# Writing schema into /schema/schema_dev.json...

# %%
# Running Validation
# !cd ../umccr-dictionary && make validate program=schema_dev
# Out:
# Using .env-sample
# Validating Data Dictionary: schema_dev
# [2024-04-19 04:45:35,583][data-simulator][   INFO] Data simulator initialization...
# [2024-04-19 04:45:35,584][data-simulator][   INFO] Loading dictionary from url http://ddvis/schema/schema_dev.json
# [2024-04-19 04:45:35,641][data-simulator][   INFO] Initializing graph...
# [2024-04-19 04:45:35,641][data-simulator][   INFO] Validating...
# [2024-04-19 04:45:35,642][data-simulator][   INFO] Done!

# %%
# Visualising data dictionary
# !open http://localhost:8080/#schema/schema_dev.json
